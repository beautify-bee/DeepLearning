# %%
import glob
import os
import sys
import sys
import json
import math
import datetime
import tensorflow as tf
import random
from tensorflow.keras import layers, Model
from tqdm import tqdm
assert tf.version.VERSION >= "2.4.0", "version of tf must greater/equal than 2.4.0"
#print(tf.__path__)
print(tf.version.VERSION)
if not os.path.exists("./save_weights"):
    os.makedirs("./save_weights")
# Out:
# 2.9.1

# %%
im_height = 224
im_width = 224
batch_size = 16
epoch = 30
num_classes = 5

#data_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))

#image_path = os.path.join(data_root, "kaggle/input/flowerdata", "flower_data")
image_path = './flower_data'
assert os.path.exists(image_path),"file:'{}' does not exist".format(image_path)

# %%
train_dir = os.path.join(image_path, "train")
val_dir = os.path.join(image_path, "val")

random.seed(0)
# class dict
data_class = [cla for cla in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, cla))]
class_num = len(data_class)
class_dict = dict((value, index) for index, value in enumerate(data_class))


train_image_list = glob.glob(train_dir + "/*/*.jpg")
random.shuffle(train_image_list)
train_num = len(train_image_list)
train_label_list = [class_dict[path.split(os.path.sep)[-2]] for path in train_image_list]

val_image_list = glob.glob(val_dir + "/*/*.jpg")
random.shuffle(val_image_list)
val_num = len(val_image_list)
val_label_list = [class_dict[path.split(os.path.sep)[-2]] for path in val_image_list]

print("using {} images for training, {} images for validation.".format(train_num, val_num))
# Out:
# using 2572 images for training, 1098 images for validation.

# %%
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]
def process_train_img(img_path, label):
    image = tf.io.read_file(img_path)
    image = tf.image.decode_jpeg(image, channels= 3)
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize_with_pad(image, im_height, im_width)
    image = tf.image.random_flip_left_right(image)
    image = (image - mean) / std
    return image, label

def process_val_img(img_path, label):
    image = tf.io.read_file(img_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize_with_crop_or_pad(image, im_height, im_width)
    image = (image - mean) / std
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_image_list, train_label_list))
train_dataset = train_dataset.shuffle(buffer_size=train_num)\
                             .map(process_train_img, num_parallel_calls=AUTOTUNE)\
                             .repeat().batch(batch_size).prefetch(AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((val_image_list, val_label_list))
val_dataset = val_dataset.map(process_val_img,num_parallel_calls = tf.data.experimental.AUTOTUNE).repeat().batch(batch_size)

# %%
class ConvBNReLU(layers.Layer):
    def __init__(self,
                 filters: int = 1,
                 kernel_size: int = 1,
                 strides: int = 1,
                 padding: str = 'same',
                 **kwargs):
        super(ConvBNReLU, self).__init__(**kwargs)

        self.conv = layers.Conv2D(filters=filters,
                                  kernel_size=kernel_size,
                                  strides=strides,
                                  padding=padding,
                                  use_bias=False,
                                  kernel_regularizer=tf.keras.regularizers.l2(4e-5),
                                  name="conv1")
        self.bn = layers.BatchNormalization(momentum=0.9, name="bn")
        self.relu = layers.ReLU()

    def call(self, inputs, training=None, **kwargs):
        x = self.conv(inputs)
        x = self.bn(x, training=training)
        x = self.relu(x)
        return x


class DWConvBN(layers.Layer):
    def __init__(self,
                 kernel_size: int = 3,
                 strides: int = 1,
                 padding: str = 'same',
                 **kwargs):
        super(DWConvBN, self).__init__(**kwargs)
        self.dw_conv = layers.DepthwiseConv2D(kernel_size=kernel_size,
                                              strides=strides,
                                              padding=padding,
                                              use_bias=False,
                                              kernel_regularizer=tf.keras.regularizers.l2(4e-5),
                                              name="dw1")
        self.bn = layers.BatchNormalization(momentum=0.9, name="bn")

    def call(self, inputs, training=None, **kwargs):
        x = self.dw_conv(inputs)
        x = self.bn(x, training=training)
        return x


class ChannelShuffle(layers.Layer):
    def __init__(self, shape, groups: int = 2, **kwargs):
        super(ChannelShuffle, self).__init__(**kwargs)
        batch_size, height, width, num_channels = shape
        assert num_channels % 2 == 0
        channel_per_group = num_channels // groups

        # Tuple of integers, does not include the samples dimension (batch size).
        self.reshape1 = layers.Reshape((height, width, groups, channel_per_group))
        self.reshape2 = layers.Reshape((height, width, num_channels))

    def call(self, inputs, **kwargs):
        x = self.reshape1(inputs)
        x = tf.transpose(x, perm=[0, 1, 2, 4, 3])
        x = self.reshape2(x)
        return x


class ChannelSplit(layers.Layer):
    def __init__(self, num_splits: int = 2, **kwargs):
        super(ChannelSplit, self).__init__(**kwargs)
        self.num_splits = num_splits

    def call(self, inputs, **kwargs):
        b1, b2 = tf.split(inputs,
                          num_or_size_splits=self.num_splits,
                          axis=-1)
        return b1, b2


def shuffle_block_s1(inputs, output_c: int, stride: int, prefix: str):
    if stride != 1:
        raise ValueError("illegal stride value.")

    assert output_c % 2 == 0
    branch_c = output_c // 2

    x1, x2 = ChannelSplit(name=prefix + "/split")(inputs)

    # main branch
    x2 = ConvBNReLU(filters=branch_c, name=prefix + "/b2_conv1")(x2)
    x2 = DWConvBN(kernel_size=3, strides=stride, name=prefix + "/b2_dw1")(x2)
    x2 = ConvBNReLU(filters=branch_c, name=prefix + "/b2_conv2")(x2)

    x = layers.Concatenate(name=prefix + "/concat")([x1, x2])
    x = ChannelShuffle(x.shape, name=prefix + "/channelshuffle")(x)

    return x


def shuffle_block_s2(inputs, output_c: int, stride: int, prefix: str):
    if stride != 2:
        raise ValueError("illegal stride value.")

    assert output_c % 2 == 0
    branch_c = output_c // 2

    # shortcut branch
    x1 = DWConvBN(kernel_size=3, strides=stride, name=prefix + "/b1_dw1")(inputs)
    x1 = ConvBNReLU(filters=branch_c, name=prefix + "/b1_conv1")(x1)

    # main branch
    x2 = ConvBNReLU(filters=branch_c, name=prefix + "/b2_conv1")(inputs)
    x2 = DWConvBN(kernel_size=3, strides=stride, name=prefix + "/b2_dw1")(x2)
    x2 = ConvBNReLU(filters=branch_c, name=prefix + "/b2_conv2")(x2)

    x = layers.Concatenate(name=prefix + "/concat")([x1, x2])
    x = ChannelShuffle(x.shape, name=prefix + "/channelshuffle")(x)

    return x


def shufflenet_v2(num_classes: int,
                  input_shape: tuple,
                  stages_repeats: list,
                  stages_out_channels: list):
    img_input = layers.Input(shape=input_shape)
    if len(stages_repeats) != 3:
        raise ValueError("expected stages_repeats as list of 3 positive ints")
    if len(stages_out_channels) != 5:
        raise ValueError("expected stages_out_channels as list of 5 positive ints")

    x = ConvBNReLU(filters=stages_out_channels[0],
                   kernel_size=3,
                   strides=2,
                   name="conv1")(img_input)

    x = layers.MaxPooling2D(pool_size=(3, 3),
                            strides=2,
                            padding='same',
                            name="maxpool")(x)

    stage_name = ["stage{}".format(i) for i in [2, 3, 4]]
    for name, repeats, output_channels in zip(stage_name,
                                              stages_repeats,
                                              stages_out_channels[1:]):
        for i in range(repeats):
            if i == 0:
                x = shuffle_block_s2(x, output_c=output_channels, stride=2, prefix=name + "_{}".format(i))
            else:
                x = shuffle_block_s1(x, output_c=output_channels, stride=1, prefix=name + "_{}".format(i))

    x = ConvBNReLU(filters=stages_out_channels[-1], name="conv5")(x)

    x = layers.GlobalAveragePooling2D(name="globalpool")(x)

    x = layers.Dense(units=num_classes, name="fc")(x)
    x = layers.Softmax()(x)

    model = Model(img_input, x, name="ShuffleNetV2_1.0")

    return model


def shufflenet_v2_x1_0(num_classes=1000, input_shape=(224, 224, 3)):
    # 权重链接: https://pan.baidu.com/s/1M2mp98Si9eT9qT436DcdOw  密码: mhts
    model = shufflenet_v2(num_classes=num_classes,
                          input_shape=input_shape,
                          stages_repeats=[4, 8, 4],
                          stages_out_channels=[24, 116, 232, 464, 1024])
    return model


def shufflenet_v2_x0_5(num_classes=1000, input_shape=(224, 224, 3)):
    model = shufflenet_v2(num_classes=num_classes,
                          input_shape=input_shape,
                          stages_repeats=[4, 8, 4],
                          stages_out_channels=[24, 48, 96, 192, 1024])
    return model


def shufflenet_v2_x2_0(num_classes=1000, input_shape=(224, 224, 3)):
    model = shufflenet_v2(num_classes=num_classes,
                          input_shape=input_shape,
                          stages_repeats=[4, 8, 4],
                          stages_out_channels=[24, 244, 488, 976, 2048])
    return model

model = shufflenet_v2_x1_0(input_shape = (im_height, im_width, 3), num_classes=num_classes)
model.summary()
# Out:
# Model: "ShuffleNetV2_1.0"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1 (ConvBNReLU)             (None, 112, 112, 24  744         ['input_1[0][0]']
#                                 )
#
#  maxpool (MaxPooling2D)         (None, 56, 56, 24)   0           ['conv1[0][0]']
#
#  stage2_0/b2_conv1 (ConvBNReLU)  (None, 56, 56, 58)  1624        ['maxpool[0][0]']
#
#  stage2_0/b1_dw1 (DWConvBN)     (None, 28, 28, 24)   312         ['maxpool[0][0]']
#
#  stage2_0/b2_dw1 (DWConvBN)     (None, 28, 28, 58)   754         ['stage2_0/b2_conv1[0][0]']
#
#  stage2_0/b1_conv1 (ConvBNReLU)  (None, 28, 28, 58)  1624        ['stage2_0/b1_dw1[0][0]']
#
#  stage2_0/b2_conv2 (ConvBNReLU)  (None, 28, 28, 58)  3596        ['stage2_0/b2_dw1[0][0]']
#
#  stage2_0/concat (Concatenate)  (None, 28, 28, 116)  0           ['stage2_0/b1_conv1[0][0]',
#                                                                   'stage2_0/b2_conv2[0][0]']
#
#  stage2_0/channelshuffle (Chann  (None, 28, 28, 116)  0          ['stage2_0/concat[0][0]']
#  elShuffle)
#
#  stage2_1/split (ChannelSplit)  ((None, 28, 28, 58)  0           ['stage2_0/channelshuffle[0][0]']
#                                 , (None, 28, 28, 58
#                                 ))
#
#  stage2_1/b2_conv1 (ConvBNReLU)  (None, 28, 28, 58)  3596        ['stage2_1/split[0][1]']
#
#  stage2_1/b2_dw1 (DWConvBN)     (None, 28, 28, 58)   754         ['stage2_1/b2_conv1[0][0]']
#
#  stage2_1/b2_conv2 (ConvBNReLU)  (None, 28, 28, 58)  3596        ['stage2_1/b2_dw1[0][0]']
#
#  stage2_1/concat (Concatenate)  (None, 28, 28, 116)  0           ['stage2_1/split[0][0]',
#                                                                   'stage2_1/b2_conv2[0][0]']
#
#  stage2_1/channelshuffle (Chann  (None, 28, 28, 116)  0          ['stage2_1/concat[0][0]']
#  elShuffle)
#
#  stage2_2/split (ChannelSplit)  ((None, 28, 28, 58)  0           ['stage2_1/channelshuffle[0][0]']
#                                 , (None, 28, 28, 58
#                                 ))
#
#  stage2_2/b2_conv1 (ConvBNReLU)  (None, 28, 28, 58)  3596        ['stage2_2/split[0][1]']
#
#  stage2_2/b2_dw1 (DWConvBN)     (None, 28, 28, 58)   754         ['stage2_2/b2_conv1[0][0]']
#
#  stage2_2/b2_conv2 (ConvBNReLU)  (None, 28, 28, 58)  3596        ['stage2_2/b2_dw1[0][0]']
#
#  stage2_2/concat (Concatenate)  (None, 28, 28, 116)  0           ['stage2_2/split[0][0]',
#                                                                   'stage2_2/b2_conv2[0][0]']
#
#  stage2_2/channelshuffle (Chann  (None, 28, 28, 116)  0          ['stage2_2/concat[0][0]']
#  elShuffle)
#
#  stage2_3/split (ChannelSplit)  ((None, 28, 28, 58)  0           ['stage2_2/channelshuffle[0][0]']
#                                 , (None, 28, 28, 58
#                                 ))
#
#  stage2_3/b2_conv1 (ConvBNReLU)  (None, 28, 28, 58)  3596        ['stage2_3/split[0][1]']
#
#  stage2_3/b2_dw1 (DWConvBN)     (None, 28, 28, 58)   754         ['stage2_3/b2_conv1[0][0]']
#
#  stage2_3/b2_conv2 (ConvBNReLU)  (None, 28, 28, 58)  3596        ['stage2_3/b2_dw1[0][0]']
#
#  stage2_3/concat (Concatenate)  (None, 28, 28, 116)  0           ['stage2_3/split[0][0]',
#                                                                   'stage2_3/b2_conv2[0][0]']
#
#  stage2_3/channelshuffle (Chann  (None, 28, 28, 116)  0          ['stage2_3/concat[0][0]']
#  elShuffle)
#
#  stage3_0/b2_conv1 (ConvBNReLU)  (None, 28, 28, 116)  13920      ['stage2_3/channelshuffle[0][0]']
#
#  stage3_0/b1_dw1 (DWConvBN)     (None, 14, 14, 116)  1508        ['stage2_3/channelshuffle[0][0]']
#
#  stage3_0/b2_dw1 (DWConvBN)     (None, 14, 14, 116)  1508        ['stage3_0/b2_conv1[0][0]']
#
#  stage3_0/b1_conv1 (ConvBNReLU)  (None, 14, 14, 116)  13920      ['stage3_0/b1_dw1[0][0]']
#
#  stage3_0/b2_conv2 (ConvBNReLU)  (None, 14, 14, 116)  13920      ['stage3_0/b2_dw1[0][0]']
#
#  stage3_0/concat (Concatenate)  (None, 14, 14, 232)  0           ['stage3_0/b1_conv1[0][0]',
#                                                                   'stage3_0/b2_conv2[0][0]']
#
#  stage3_0/channelshuffle (Chann  (None, 14, 14, 232)  0          ['stage3_0/concat[0][0]']
#  elShuffle)
#
#  stage3_1/split (ChannelSplit)  ((None, 14, 14, 116  0           ['stage3_0/channelshuffle[0][0]']
#                                 ),
#                                  (None, 14, 14, 116
#                                 ))
#
#  stage3_1/b2_conv1 (ConvBNReLU)  (None, 14, 14, 116)  13920      ['stage3_1/split[0][1]']
#
#  stage3_1/b2_dw1 (DWConvBN)     (None, 14, 14, 116)  1508        ['stage3_1/b2_conv1[0][0]']
#
#  stage3_1/b2_conv2 (ConvBNReLU)  (None, 14, 14, 116)  13920      ['stage3_1/b2_dw1[0][0]']
#
#  stage3_1/concat (Concatenate)  (None, 14, 14, 232)  0           ['stage3_1/split[0][0]',
#                                                                   'stage3_1/b2_conv2[0][0]']
#
#  stage3_1/channelshuffle (Chann  (None, 14, 14, 232)  0          ['stage3_1/concat[0][0]']
#  elShuffle)
#
#  stage3_2/split (ChannelSplit)  ((None, 14, 14, 116  0           ['stage3_1/channelshuffle[0][0]']
#                                 ),
#                                  (None, 14, 14, 116
#                                 ))
#
#  stage3_2/b2_conv1 (ConvBNReLU)  (None, 14, 14, 116)  13920      ['stage3_2/split[0][1]']
#
#  stage3_2/b2_dw1 (DWConvBN)     (None, 14, 14, 116)  1508        ['stage3_2/b2_conv1[0][0]']
#
#  stage3_2/b2_conv2 (ConvBNReLU)  (None, 14, 14, 116)  13920      ['stage3_2/b2_dw1[0][0]']
#
#  stage3_2/concat (Concatenate)  (None, 14, 14, 232)  0           ['stage3_2/split[0][0]',
#                                                                   'stage3_2/b2_conv2[0][0]']
#
#  stage3_2/channelshuffle (Chann  (None, 14, 14, 232)  0          ['stage3_2/concat[0][0]']
#  elShuffle)
#
#  stage3_3/split (ChannelSplit)  ((None, 14, 14, 116  0           ['stage3_2/channelshuffle[0][0]']
#                                 ),
#                                  (None, 14, 14, 116
#                                 ))
#
#  stage3_3/b2_conv1 (ConvBNReLU)  (None, 14, 14, 116)  13920      ['stage3_3/split[0][1]']
#
#  stage3_3/b2_dw1 (DWConvBN)     (None, 14, 14, 116)  1508        ['stage3_3/b2_conv1[0][0]']
#
#  stage3_3/b2_conv2 (ConvBNReLU)  (None, 14, 14, 116)  13920      ['stage3_3/b2_dw1[0][0]']
#
#  stage3_3/concat (Concatenate)  (None, 14, 14, 232)  0           ['stage3_3/split[0][0]',
#                                                                   'stage3_3/b2_conv2[0][0]']
#
#  stage3_3/channelshuffle (Chann  (None, 14, 14, 232)  0          ['stage3_3/concat[0][0]']
#  elShuffle)
#
#  stage3_4/split (ChannelSplit)  ((None, 14, 14, 116  0           ['stage3_3/channelshuffle[0][0]']
#                                 ),
#                                  (None, 14, 14, 116
#                                 ))
#
#  stage3_4/b2_conv1 (ConvBNReLU)  (None, 14, 14, 116)  13920      ['stage3_4/split[0][1]']
#
#  stage3_4/b2_dw1 (DWConvBN)     (None, 14, 14, 116)  1508        ['stage3_4/b2_conv1[0][0]']
#
#  stage3_4/b2_conv2 (ConvBNReLU)  (None, 14, 14, 116)  13920      ['stage3_4/b2_dw1[0][0]']
#
#  stage3_4/concat (Concatenate)  (None, 14, 14, 232)  0           ['stage3_4/split[0][0]',
#                                                                   'stage3_4/b2_conv2[0][0]']
#
#  stage3_4/channelshuffle (Chann  (None, 14, 14, 232)  0          ['stage3_4/concat[0][0]']
#  elShuffle)
#
#  stage3_5/split (ChannelSplit)  ((None, 14, 14, 116  0           ['stage3_4/channelshuffle[0][0]']
#                                 ),
#                                  (None, 14, 14, 116
#                                 ))
#
#  stage3_5/b2_conv1 (ConvBNReLU)  (None, 14, 14, 116)  13920      ['stage3_5/split[0][1]']
#
#  stage3_5/b2_dw1 (DWConvBN)     (None, 14, 14, 116)  1508        ['stage3_5/b2_conv1[0][0]']
#
#  stage3_5/b2_conv2 (ConvBNReLU)  (None, 14, 14, 116)  13920      ['stage3_5/b2_dw1[0][0]']
#
#  stage3_5/concat (Concatenate)  (None, 14, 14, 232)  0           ['stage3_5/split[0][0]',
#                                                                   'stage3_5/b2_conv2[0][0]']
#
#  stage3_5/channelshuffle (Chann  (None, 14, 14, 232)  0          ['stage3_5/concat[0][0]']
#  elShuffle)
#
#  stage3_6/split (ChannelSplit)  ((None, 14, 14, 116  0           ['stage3_5/channelshuffle[0][0]']
#                                 ),
#                                  (None, 14, 14, 116
#                                 ))
#
#  stage3_6/b2_conv1 (ConvBNReLU)  (None, 14, 14, 116)  13920      ['stage3_6/split[0][1]']
#
#  stage3_6/b2_dw1 (DWConvBN)     (None, 14, 14, 116)  1508        ['stage3_6/b2_conv1[0][0]']
#
#  stage3_6/b2_conv2 (ConvBNReLU)  (None, 14, 14, 116)  13920      ['stage3_6/b2_dw1[0][0]']
#
#  stage3_6/concat (Concatenate)  (None, 14, 14, 232)  0           ['stage3_6/split[0][0]',
#                                                                   'stage3_6/b2_conv2[0][0]']
#
#  stage3_6/channelshuffle (Chann  (None, 14, 14, 232)  0          ['stage3_6/concat[0][0]']
#  elShuffle)
#
#  stage3_7/split (ChannelSplit)  ((None, 14, 14, 116  0           ['stage3_6/channelshuffle[0][0]']
#                                 ),
#                                  (None, 14, 14, 116
#                                 ))
#
#  stage3_7/b2_conv1 (ConvBNReLU)  (None, 14, 14, 116)  13920      ['stage3_7/split[0][1]']
#
#  stage3_7/b2_dw1 (DWConvBN)     (None, 14, 14, 116)  1508        ['stage3_7/b2_conv1[0][0]']
#
#  stage3_7/b2_conv2 (ConvBNReLU)  (None, 14, 14, 116)  13920      ['stage3_7/b2_dw1[0][0]']
#
#  stage3_7/concat (Concatenate)  (None, 14, 14, 232)  0           ['stage3_7/split[0][0]',
#                                                                   'stage3_7/b2_conv2[0][0]']
#
#  stage3_7/channelshuffle (Chann  (None, 14, 14, 232)  0          ['stage3_7/concat[0][0]']
#  elShuffle)
#
#  stage4_0/b2_conv1 (ConvBNReLU)  (None, 14, 14, 232)  54752      ['stage3_7/channelshuffle[0][0]']
#
#  stage4_0/b1_dw1 (DWConvBN)     (None, 7, 7, 232)    3016        ['stage3_7/channelshuffle[0][0]']
#
#  stage4_0/b2_dw1 (DWConvBN)     (None, 7, 7, 232)    3016        ['stage4_0/b2_conv1[0][0]']
#
#  stage4_0/b1_conv1 (ConvBNReLU)  (None, 7, 7, 232)   54752       ['stage4_0/b1_dw1[0][0]']
#
#  stage4_0/b2_conv2 (ConvBNReLU)  (None, 7, 7, 232)   54752       ['stage4_0/b2_dw1[0][0]']
#
#  stage4_0/concat (Concatenate)  (None, 7, 7, 464)    0           ['stage4_0/b1_conv1[0][0]',
#                                                                   'stage4_0/b2_conv2[0][0]']
#
#  stage4_0/channelshuffle (Chann  (None, 7, 7, 464)   0           ['stage4_0/concat[0][0]']
#  elShuffle)
#
#  stage4_1/split (ChannelSplit)  ((None, 7, 7, 232),  0           ['stage4_0/channelshuffle[0][0]']
#                                  (None, 7, 7, 232))
#
#  stage4_1/b2_conv1 (ConvBNReLU)  (None, 7, 7, 232)   54752       ['stage4_1/split[0][1]']
#
#  stage4_1/b2_dw1 (DWConvBN)     (None, 7, 7, 232)    3016        ['stage4_1/b2_conv1[0][0]']
#
#  stage4_1/b2_conv2 (ConvBNReLU)  (None, 7, 7, 232)   54752       ['stage4_1/b2_dw1[0][0]']
#
#  stage4_1/concat (Concatenate)  (None, 7, 7, 464)    0           ['stage4_1/split[0][0]',
#                                                                   'stage4_1/b2_conv2[0][0]']
#
#  stage4_1/channelshuffle (Chann  (None, 7, 7, 464)   0           ['stage4_1/concat[0][0]']
#  elShuffle)
#
#  stage4_2/split (ChannelSplit)  ((None, 7, 7, 232),  0           ['stage4_1/channelshuffle[0][0]']
#                                  (None, 7, 7, 232))
#
#  stage4_2/b2_conv1 (ConvBNReLU)  (None, 7, 7, 232)   54752       ['stage4_2/split[0][1]']
#
#  stage4_2/b2_dw1 (DWConvBN)     (None, 7, 7, 232)    3016        ['stage4_2/b2_conv1[0][0]']
#
#  stage4_2/b2_conv2 (ConvBNReLU)  (None, 7, 7, 232)   54752       ['stage4_2/b2_dw1[0][0]']
#
#  stage4_2/concat (Concatenate)  (None, 7, 7, 464)    0           ['stage4_2/split[0][0]',
#                                                                   'stage4_2/b2_conv2[0][0]']
#
#  stage4_2/channelshuffle (Chann  (None, 7, 7, 464)   0           ['stage4_2/concat[0][0]']
#  elShuffle)
#
#  stage4_3/split (ChannelSplit)  ((None, 7, 7, 232),  0           ['stage4_2/channelshuffle[0][0]']
#                                  (None, 7, 7, 232))
#
#  stage4_3/b2_conv1 (ConvBNReLU)  (None, 7, 7, 232)   54752       ['stage4_3/split[0][1]']
#
#  stage4_3/b2_dw1 (DWConvBN)     (None, 7, 7, 232)    3016        ['stage4_3/b2_conv1[0][0]']
#
#  stage4_3/b2_conv2 (ConvBNReLU)  (None, 7, 7, 232)   54752       ['stage4_3/b2_dw1[0][0]']
#
#  stage4_3/concat (Concatenate)  (None, 7, 7, 464)    0           ['stage4_3/split[0][0]',
#                                                                   'stage4_3/b2_conv2[0][0]']
#
#  stage4_3/channelshuffle (Chann  (None, 7, 7, 464)   0           ['stage4_3/concat[0][0]']
#  elShuffle)
#
#  conv5 (ConvBNReLU)             (None, 7, 7, 1024)   479232      ['stage4_3/channelshuffle[0][0]']
#
#  globalpool (GlobalAveragePooli  (None, 1024)        0           ['conv5[0][0]']
#  ng2D)
#
#  fc (Dense)                     (None, 5)            5125        ['globalpool[0][0]']
#
#  softmax (Softmax)              (None, 5)            0           ['fc[0][0]']
#
# ==================================================================================================
# Total params: 1,274,909
# Trainable params: 1,258,729
# Non-trainable params: 16,180
# __________________________________________________________________________________________________
